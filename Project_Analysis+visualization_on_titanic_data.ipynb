# %%
#what is gender ratio of survived passenger.
#From where max & min passenger board to titanic also define their avg age
# tell me the name of the youngest passenger on titanic.
# tell me the name of oldest passenger on titanic.
# tell the number of total count of survived & unsurvived passengers
# what is the highest & lowest fare on titanic.
# which class have highest ticket with respect to fare.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'E:\DA_Data\train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 269          270         1       1               Bissette, Miss. Amelia
# 802          803         1       1  Carter, Master. William Thornton II
# 724          725         1       1        Chambers, Mr. Norman Campbell
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 269  female  35.0      0      0  PC 17760  135.6333      C99        S
# 802    male  11.0      1      2    113760  120.0000  B96 B98        S
# 724    male  27.0      1      0    113806   53.1000       E8        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df1=df.fillna(method='ffill')

# %%
df1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       0
# dtype: int64

# %%
df2=df1.fillna(method='backfill')

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C85        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   C85        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  C123        S

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#what is gender ratio of survived passenger.

df2.loc[df2['Survived']==1,['Sex','Survived']]

# Conclusion----->> there are 342 genders who are Survived in this data
# Out:
#         Sex  Survived
# 1    female         1
# 2    female         1
# 3    female         1
# 8    female         1
# 9    female         1
# ..      ...       ...
# 875  female         1
# 879  female         1
# 880  female         1
# 887  female         1
# 889    male         1
#
# [342 rows x 2 columns]

# %%
#From where max & min passenger board to titanic and also define their avg age

df2[['Embarked','Fare']].aggregate([min,max]),df2['Age'].mean()

# Coclusion----->> In this there are minimum passenger board from the 'C' Embarked and maximum passenger board from the 'S' and the avg of 'AGE' is 29.58
# Out:
# (    Embarked      Fare
#  min        C    0.0000
#  max        S  512.3292,
#  29.581560044893376)

# %%
# tell me the name of the youngest passenger on titanic.

youngest_and_oldest_Passenger=df2[['Name','Age']].aggregate([min,max])
youngest_and_oldest_Passenger


#Conclusion---->> in this data the youngest passenger age is "0.42" and oldest passenger age is "80.00" and shown in bellow graph
# Out:
#                             Name    Age
# min          Abbing, Mr. Anthony   0.42
# max  van Melkebeke, Mr. Philemon  80.00

# %%
sns.barplot('Name','Age',data=youngest_and_oldest_Passenger)
# Out:
# C:\Users\Deepak kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Name', ylabel='Age'>

# %%
#  tell the number of total count of survived & unsurvived passengers

df2.loc[df2['Survived']==1,['Name','Survived']]

# Conclussion---->>there are '342' passenger with Name who are Survived
# Out:
#                                                   Name  Survived
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)         1
# ..                                                 ...       ...
# 875                   Najib, Miss. Adele Kiamie "Jane"         1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)         1
# 887                       Graham, Miss. Margaret Edith         1
# 889                              Behr, Mr. Karl Howell         1
#
# [342 rows x 2 columns]

# %%
df2.loc[df2['Survived']==0,['Name','Survived']]

# Conclussion---->>there are '549' passenger with Name who are not Survived
# Out:
#                                          Name  Survived
# 0                     Braund, Mr. Owen Harris         0
# 4                    Allen, Mr. William Henry         0
# 5                            Moran, Mr. James         0
# 6                     McCarthy, Mr. Timothy J         0
# 7              Palsson, Master. Gosta Leonard         0
# ..                                        ...       ...
# 884                    Sutehall, Mr. Henry Jr         0
# 885      Rice, Mrs. William (Margaret Norton)         0
# 886                     Montvila, Rev. Juozas         0
# 888  Johnston, Miss. Catherine Helen "Carrie"         0
# 890                       Dooley, Mr. Patrick         0
#
# [549 rows x 2 columns]

# %%
# what is the highest & lowest fare on titanic.


Min_and_max_Fare_of_passenger=df2[['Cabin','Fare']].aggregate([min,max])
Min_and_max_Fare_of_passenger


# Conclussion---->> in this data the minimum Fare is '0.00' of 'A10' Cabin and the maximum Fare is '512.32' of 'T Cabin'
# Out:
#     Cabin      Fare
# min   A10    0.0000
# max     T  512.3292

# %%
sns.barplot('Cabin','Fare',data=Min_and_max_Fare_of_passenger)
# Out:
# C:\Users\Deepak kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Cabin', ylabel='Fare'>

# %%
# which class have highest ticket with respect to fare.

Highest_Fare_of_Class=df2[['Pclass','Fare']].max()
Highest_Fare_of_Class
# Out:
# Pclass      3.0000
# Fare      512.3292
# dtype: float64

# %%
#From where max & min passenger board to titanic and also define their avg age
board_pass=df["Embarked"].value_counts()

# %%
board_pass
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
board_pass.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df[['Embarked','Age']].value_counts()
# Out:
# Embarked  Age
# S         24.0    23
#           28.0    23
#           19.0    22
#           22.0    21
#           21.0    21
#                   ..
# Q         18.0     1
#           15.0     1
#           8.0      1
#           7.0      1
# S         80.0     1
# Length: 162, dtype: int64

# %%
df.loc[df['Embarked']=='S',['Embarked','Age']]
# Out:
#     Embarked   Age
# 0          S  22.0
# 2          S  26.0
# 3          S  35.0
# 4          S  35.0
# 6          S  54.0
# ..       ...   ...
# 883        S  28.0
# 884        S  25.0
# 886        S  27.0
# 887        S  19.0
# 888        S   NaN
#
# [644 rows x 2 columns]

# %%
#  tell the number of total count of survived & unsurvived passengers

survivev=df2.loc[df2['Survived']==1,['Survived']]

# %%
#  tell the number of total count of survived & unsurvived passengers

unsurvived=df2.loc[df2['Survived']==0,['Survived']]

# %%
sns.countplot('Survived',data=df)
# Out:
# C:\Users\Deepak kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>
